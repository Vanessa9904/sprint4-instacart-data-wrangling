# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario general del revisor</b> <a class="tocSkip"></a><br />
# Status del proyecto: <b>Aprobado</b>
# </div>

# %% [markdown]
# ¡Hola!<br />
# Soy **Francisco Cortés**, estoy contento de revisar tu proyecto y ser parte de tu proceso de aprendizaje.
# A lo largo del texto, haré algunas observaciones sobre mejoras en el código y también haré comentarios sobre tus percepciones sobre el tema. Si existe algún error en el código, no te preocupes, estoy aquí para ayudarte a mejorarlo, en la primera iteración te lo señalaré para que tengas la oportunidad de corregirlo, pero si aún no encuentras una solución para esta tarea, te daré una pista más precisa en la próxima iteración y también algunos ejemplos prácticos. Estaré abierto a retroalimentación y discusiones sobre el tema.<br />
# Encontrarás mis comentarios a continuación - **por favor no los muevas, modifiques o borres**.
# Revisaré cuidadosamente tu código para comprobar que se han cumplido con los requisitos y te proporcionaré mis comentarios en cajas verdes, amarillas o rojas como esta:
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Si la ejecución fue perfecta succesfully.
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Si existe alguna recomendación para que tu código mejore.
# </div>
#
# <div class="alert alert-block alert-danger">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Si existen correcciones necesarias para cumplir con los requisitos. El trabajo no puede ser aceptado si hay alguna caja roja.
# </div>
#
# Puedes responderme de la siguiente manera:
#
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante.</b> <a class="tocSkip"></a>
# </div>

# %% [markdown]
# # ¡Llena ese carrito!

# %% [markdown]
# # Introducción
#
# Instacart es una plataforma de entregas de comestibles donde la clientela puede registrar un pedido y hacer que se lo entreguen, similar a Uber Eats y Door Dash.
# El conjunto de datos que te hemos proporcionado tiene modificaciones del original. Redujimos el tamaño del conjunto para que tus cálculos se hicieran más rápido e introdujimos valores ausentes y duplicados. Tuvimos cuidado de conservar las distribuciones de los datos originales cuando hicimos los cambios.
#
# Debes completar tres pasos. Para cada uno de ellos, escribe una breve introducción que refleje con claridad cómo pretendes resolver cada paso, y escribe párrafos explicatorios que justifiquen tus decisiones al tiempo que avanzas en tu solución.  También escribe una conclusión que resuma tus hallazgos y elecciones.

# %% [markdown]
# ## Diccionario de datos
#
# Hay cinco tablas en el conjunto de datos, y tendrás que usarlas todas para hacer el preprocesamiento de datos y el análisis exploratorio de datos. A continuación se muestra un diccionario de datos que enumera las columnas de cada tabla y describe los datos que contienen.
#
# - `instacart_orders.csv`: cada fila corresponde a un pedido en la aplicación Instacart.
#     - `'order_id'`: número de ID que identifica de manera única cada pedido.
#     - `'user_id'`: número de ID que identifica de manera única la cuenta de cada cliente.
#     - `'order_number'`: el número de veces que este cliente ha hecho un pedido.
#     - `'order_dow'`: día de la semana en que se hizo el pedido (0 si es domingo).
#     - `'order_hour_of_day'`: hora del día en que se hizo el pedido.
#     - `'days_since_prior_order'`: número de días transcurridos desde que este cliente hizo su pedido anterior.
# - `products.csv`: cada fila corresponde a un producto único que pueden comprar los clientes.
#     - `'product_id'`: número ID que identifica de manera única cada producto.
#     - `'product_name'`: nombre del producto.
#     - `'aisle_id'`: número ID que identifica de manera única cada categoría de    pasillo de víveres.
#      - `'department_id'`: número ID que identifica de manera única cada departamento de víveres.
# - `order_products.csv`: cada fila corresponde a un artículo pedido en un pedido.
#     - `'order_id'`: número de ID que identifica de manera única cada pedido.
#     - `'product_id'`: número ID que identifica de manera única cada producto.
#     - `'add_to_cart_order'`: el orden secuencial en el que se añadió cada artículo en el carrito.
#     - `'reordered'`: 0 si el cliente nunca ha pedido este producto antes, 1 si lo ha pedido.
# - `aisles.csv`
#     - `'aisle_id'`: número ID que identifica de manera única cada categoría de pasillo de víveres.
#     - `'aisle'`: nombre del pasillo.
# - `departments.csv`
#     - `'department_id'`: número ID que identifica de manera única cada departamento de víveres.
#     - `'department'`: nombre del departamento.

# %% [markdown]
# # Paso 1. Descripción de los datos
#
# Lee los archivos de datos (`/datasets/instacart_orders.csv`, `/datasets/products.csv`, `/datasets/aisles.csv`, `/datasets/departments.csv` y `/datasets/order_products.csv`) con `pd.read_csv()` usando los parámetros adecuados para leer los datos correctamente. Verifica la información para cada DataFrame creado.

# %% [markdown]
# ## Plan de solución
#
# Escribe aquí tu plan de solución para el Paso 1. Descripción de los datos.

# %%
 # importar librerías
import pandas as pd
from matplotlib import pyplot as plt

# %%
# leer conjuntos de datos en los DataFrames
instacart_orders= pd.read_csv("D:/Documents/Data_analisys/sprint_4/instacart_orders.csv")
products = pd.read_csv("D:/Documents/Data_analisys/sprint_4/products.csv")
departments = pd.read_csv("D:/Documents/Data_analisys/sprint_4/departments.csv")
order_products = pd.read_csv("D:/Documents/Data_analisys/sprint_4/order_products.csv")
aisles = pd.read_csv("D:/Documents/Data_analisys/sprint_4/aisles.csv")

# %%
# mostrar información del DataFrame instacart-orders
instacart_orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 478967 entries, 0 to 478966
# Data columns (total 1 columns):
#  #   Column                                                                            Non-Null Count   Dtype
# ---  ------                                                                            --------------   -----
#  0   order_id;user_id;order_number;order_dow;order_hour_of_day;days_since_prior_order  478967 non-null  object
# dtypes: object(1)
# memory usage: 3.7+ MB

# %%
# mostrar información del DataFrame
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49694 entries, 0 to 49693
# Data columns (total 1 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   product_id;product_name;aisle_id;department_id  49694 non-null  object
# dtypes: object(1)
# memory usage: 388.4+ KB

# %%
# mostrar información del DataFrame
departments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 1 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   department_id;department  21 non-null     object
# dtypes: object(1)
# memory usage: 296.0+ bytes

# %%
# mostrar información del DataFrame
order_products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4545007 entries, 0 to 4545006
# Data columns (total 1 columns):
#  #   Column                                           Dtype
# ---  ------                                           -----
#  0   order_id;product_id;add_to_cart_order;reordered  object
# dtypes: object(1)
# memory usage: 34.7+ MB

# %%
# mostrar información del DataFrame
aisles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134 entries, 0 to 133
# Data columns (total 1 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   aisle_id;aisle  134 non-null    object
# dtypes: object(1)
# memory usage: 1.2+ KB

# %% [markdown]
# ### Conclusiones
# 1.**Problema en la estructura de los archivos:** Todas las tablas cargaron una sola columna con múltiples campos concatenados por punto y coma (;), lo cual indica que los archivos CSV no se están leyendo correctamente.
#
# 2.**El delimitador** El delimitador de los archivos no es la coma (,)por defecto, sino el punto y coma (;)
#
# 3.**Cantidad de registros:** estos pueden verse afectados por el delimietador
# _instacart_orders_ contiene 478,967 registros.
# _products contiene_ 49,694 productos.
# _departments_ tiene 21 departamentos.
# _order_products_ es la tabla más grande con más de 4.5 millones de registros, al parecer contiene todos los datos de cada producto en una columna
# _aisles_ tiene 134 pasillos distintos.
#
# 4.**Datos no nulos:**
# Todas las tablas muestran que no hay valores nulos en su única columna, debido a que cada fila aparece como una cadena completa y no hay campos individuales evaluables.
#
# 5.**Tipo de datos:** Todas las columnas son de tipo object (es decir, texto), lo cual es coherente con que no se han separado en columnas individuales.

# %% [markdown]
# # Paso 2. Preprocesamiento de los datos
#
# Preprocesa los datos de la siguiente manera:
#
# - Verifica y corrige los tipos de datos (por ejemplo, asegúrate de que las columnas de ID sean números enteros).
# - Identifica y completa los valores ausentes.
# - Identifica y elimina los valores duplicados.
#
# Asegúrate de explicar qué tipos de valores ausentes y duplicados encontraste, cómo los completaste o eliminaste y por qué usaste esos métodos. ¿Por qué crees que estos valores ausentes y duplicados pueden haber estado presentes en el conjunto de datos?

# %% [markdown]
# ## Plan de solución
#
# Escribe aquí tu plan para el Paso 2. Preprocesamiento de los datos.
#
# 1. volver a leer los archivos utilizando el parámetro **sep=';'** esto separará correctamente cada columna según el delimitador (;) ,  y cada DataFrame tendrá las columnas bien distribuidas.
# 2. Confirmar que las columnas de ID (order_id, user_id, product_id, aisle_id, department_id) sean de tipo int64.
# 3. Validar que days_since_prior_order siga siendo float64 (puede tener valores faltantes o no enteros).
# 4. Completar o manejar de forma adecuada los valores nulos para mantener la calidad del análisis, en el caso de **days_since_prior_order** en **instacart_order** los valores nulos probablemente corresponden a la primera compra de cada usuario. Se completarán con 0 (significa “no hay un pedido anterior”) y  **products_name** en **product** se puede Consultar si el product_id correspondiente existe en los demás registros. Si no hay forma de recuperar el nombre, esos registros se eliminarán
# 5. Identificación y eliminación de duplicados

# %% [markdown]
# ## Encuentra y elimina los valores duplicados (y describe cómo tomaste tus decisiones).

# %% [markdown]
# ### `orders` data frame

# %%
instacart_orders= pd.read_csv('/datasets/instacart_orders.csv', sep = ';')
products = pd.read_csv('/datasets/products.csv', sep = ';')
departments = pd.read_csv('/datasets/departments.csv',sep = ';')
order_products = pd.read_csv('/datasets/order_products.csv', sep = ';')
aisles = pd.read_csv('/datasets/aisles.csv', sep = ';')

# %%
#Revisa pedidos duplicados
instacart_orders[instacart_orders.duplicated(keep=False)].sort_values('order_id')
# Out:
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 354993    391768    57671            19          3                  2
# 371905    391768    57671            19          3                  2
# 119251    408114    68324             4          3                  2
# 321100    408114    68324             4          3                  2
# 394347    467134    63189            21          3                  2
# 250626    467134    63189            21          3                  2
# 99462     794638    50898            24          3                  2
# 145574    794638    50898            24          3                  2
# 311713   1021560    53767             3          3                  2
# 242618   1021560    53767             3          3                  2
# 164581   1112182   202304            84          3                  2
# 273805   1112182   202304            84          3                  2
# ...

# %%
duplicated_rows = instacart_orders[instacart_orders.duplicated()]
print (duplicated_rows)
# Out:
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 145574    794638    50898            24          3                  2
# 223105   2160484   107525            16          3                  2
# 230807   1918001   188546            14          3                  2
# 266232   1782114   106752             1          3                  2
# 273805   1112182   202304            84          3                  2
# 284038   2845099    31189            11          3                  2
# 311713   1021560    53767             3          3                  2
# 321100    408114    68324             4          3                  2
# 323900   1919531   191501            32          3                  2
# 345917   2232988    82565             1          3                  2
# 371905    391768    57671            19          3                  2
# 394347    467134    63189            21          3                  2
# ...

# %% [markdown]
# ¿Tienes líneas duplicadas? Si sí, ¿qué tienen en común?
#
# Sí, hay líneas duplicadas. Todas las columnas tienen los mismos valores, no sólo order_id.Los duplicados ocurren porque existen filas idénticas, posiblemente por errores en la recolección de datos o múltiples registros del mismo evento, todos son pares de filas duplicadas.

# %%
# Basándote en tus hallazgos,
# Verifica todos los pedidos que se hicieron el miércoles a las 2:00 a.m.

wednesday_2am = instacart_orders[
    (instacart_orders['order_dow'] == 3) &
    (instacart_orders['order_hour_of_day'] == 2)
]
print (wednesday_2am)
# Out:
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 4838     2766110   162084            41          3                  2
# 5156     2190225   138285            18          3                  2
# 15506     553049    58599            13          3                  2
# 18420     382357   120200            19          3                  2
# 24691     690242    77357             2          3                  2
# ...          ...      ...           ...        ...                ...
# 457013   3384021    14881             6          3                  2
# 458816    910166   164782            18          3                  2
# 459635   1680532   106435             6          3                  2
# 468324    222962    54979            59          3                  2
# 477526   2592344    46860            38          3                  2
#
#         days_since_prior_order
# 4838                      16.0
# 5156                      11.0
# ...

# %% [markdown]
# ¿Qué sugiere este resultado?
#
# Hay 121 registros, lo cual indica que no es un comportamiento aislado, puede deberse a hábitos nocturnos o zona horaria del servidor y days_since_prior_order tine un amplio rango lo que sugiere que es algo aleatorio y no un ciclo semanal

# %%
# Elimina los pedidos duplicados
instacart_orders_cleaned = instacart_orders.drop_duplicates()

# %%
# Vuelve a verificar si hay filas duplicadas
instacart_orders_cleaned.duplicated().sum()
# Out:
# 0

# %%
# Vuelve a verificar únicamente si hay IDs duplicados de pedidos
instacart_orders_cleaned['order_id'].duplicated().sum()
# Out:
# 0

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br />
#
# Los duplicados fueron eliminados correctamente pero estos se guardaron en una variable que no se vuelve a usar, recomiendo guardar los cambios en la misma variable, ejemplos:
#
# ```
# # Ejemplo 1:
# instacart_orders.drop_duplicates(inplace = True)
#
# # Ejemplo 2:
# instacart_orders = instacart_orders.drop_duplicates()
# ```
#
# </div>

# %% [markdown]
# Describe los hallazgos y lo que hiciste con ellos
#
#
# 1.Las filas duplicadas eran completamente idénticas en todas las columnas, no solo en order_id.
# 2.Un total de 121 registros para pedidos el miercóles 2:00 am quiere decir que no es un evento raro ni puntual.
# 3.Los valores en days_since_prior_order varían bastante, lo que sugiere que no es un patrón cíclico o semanal. Es probable que algunos usuarios tengan hábitos de compra nocturnos.
#
# Limpieza de duplicados
# Se repitió la consulta de duplicados y se confirmó que ya no existen filas duplicadas en el DataFrame limpio.

# %% [markdown]
# ### `products` data frame

# %%
# Verifica si hay filas totalmente duplicadas
products_duplicated = products.duplicated().sum()
print (products_duplicated)
# Out:
# 0

# %%
# Revisa únicamente si hay ID de productos duplicados
products['product_id'].duplicated().sum()
# Out:
# 0

# %%
# Revisa únicamente si hay nombres duplicados de productos (convierte los nombres a letras mayúsculas para compararlos mejor)
products['product_name_upper'] = products['product_name'].str.upper()
products['product_name_upper'].duplicated().sum()
# Out:
# 1361

# %%
# Revisa si hay nombres duplicados de productos no faltantes
products[(~products['product_name_upper'].isna())& (products['product_name_upper'].duplicated())]
# Out:
#        product_id                                     product_name  aisle_id  \
# 2058         2059                                  Biotin 1000 Mcg        47
# 5455         5456                 Green Tea With Ginseng and Honey        96
# 5558         5559                           Cream Of Mushroom Soup        69
# 7558         7559                        Cinnamon Rolls with Icing       105
# 9037         9038                           American Cheese slices        21
# ...           ...                                              ...       ...
# 49689       49690                    HIGH PERFORMANCE ENERGY DRINK        64
# 49690       49691                    ORIGINAL PANCAKE & WAFFLE MIX       130
# 49691       49692  ORGANIC INSTANT OATMEAL LIGHT MAPLE BROWN SUGAR       130
# 49692       49693                           SPRING WATER BODY WASH       127
# 49693       49694                          BURRITO- STEAK & CHEESE        38
#
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br />
# Bien hecho!<br/>
# Los datos han sido revisados apropiadamente
# </div>

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
# hallazgos
# 1. No hay filas completamente duplicadas en el DataFrame products, indica que no hay entradas idénticas en todas sus columnas.
# 2. Hay 1361 productos con nombres duplicados (ignorando mayúsculas)
# 3. 104 filas detectadas con nombres duplicados (ignorando mayúsculas y valores nulos) Muestra productos que aparecen más de una vez con nombres visualmente iguales (en mayúsculas), pero posiblemente con diferentes product_id, aisle_id o department_id.
#
# Transformé los nombres de producto a mayúsculas (product_name_upper) para normalizar los textos y detectar duplicados reales sin errores por capitalización.
#
# Identifiqué los productos con nombres duplicados y extraje un subconjunto (104 filas) que muestran claramente cuáles nombres se repiten.

# %% [markdown]
# ### `departments` data frame

# %%
# Revisa si hay filas totalmente duplicadas


departments_duplicated = departments.duplicated().sum()
print(departments_duplicated)
# Out:
# 0

# %%
# Revisa únicamente si hay IDs duplicadas de depart

departments['department_id'].duplicated().sum()
# Out:
# 0

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
# 1. No se encontraron filas completamente duplicadas en el DataFrame, esto significa que cada combinación de columnas en cada fila es única.
# 2. No hay valores repetidos en la columna department_id quiere decir , que funciona correctamente como clave única.
#
# Se ejecutaron verificaciones para detectar duplicados, tanto a nivel de fila completa como en la columna clave (department_id).
#
# No fue necesario aplicar limpieza, ya que los datos no presentan duplicaciones, son consistentes.

# %% [markdown]
# ### `aisles` data frame

# %%
# Revisa si hay filas totalmente duplicadas
aisles_duplicated = aisles.duplicated().sum()
print(aisles_duplicated)
# Out:
# 0

# %%
# Revisa únicamente si hay IDs duplicadas de pasillos
aisles['aisle_id'].duplicated().sum()
# Out:
# 0

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
# 1. No se identificaron filas completamente duplicadas en el DataFrame aisles, lo que indica que cada fila tiene una combinación única de valores en sus columnas.
# 2.  La columna aisle_id no contiene valores repetidos, lo que confirma que actúa adecuadamente como una clave única.
#
# Dado que no se encontraron repeticiones, no fue necesario aplicar procesos de limpieza, lo que evidencia que los datos son coherentes y están correctamente estructurados.

# %% [markdown]
# ### `order_products` data frame

# %%
# Revisa si hay filas totalmente duplicadas


order_products_duplicated = order_products.duplicated().sum()
print(order_products_duplicated)
# Out:
# 0

# %%
# Vuelve a verificar si hay cualquier otro duplicado engañoso
order_products.duplicated(subset=['order_id', 'product_id']).sum()
# Out:
# 0

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br />
# Correcto!<br/>
# Estos últimos dataframes no cuentan con filas totalmente duplicadas.
#
# </div>

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
# 1. No se encontraron filas completamente duplicadas en el DataFrame, lo que confirma que cada registro es único considerando todas las columnas: order_id, product_id, add_to_cart_order y reordered.
#
# También se realizó una verificación adicional para detectar duplicados engañosos, revisando si existían combinaciones repetidas de order_id y product_id. No se detectaron registros duplicados bajo este criterio, lo que indica que no hay productos registrados más de una vez en el mismo pedido

# %% [markdown]
# ## Encuentra y elimina los valores ausentes
#
# Al trabajar con valores duplicados, pudimos observar que también nos falta investigar valores ausentes:
#
# * La columna `'product_name'` de la tabla products.
# * La columna `'days_since_prior_order'` de la tabla orders.
# * La columna `'add_to_cart_order'` de la tabla order_productos.

# %% [markdown]
# ### `products` data frame

# %%
# Encuentra los valores ausentes en la columna 'product_name'
missing_product_name = products[products['product_name'].isnull()]
print(missing_product_name)
# Out:
#        product_id product_name  aisle_id  department_id product_name_upper
# 37             38          NaN       100             21                NaN
# 71             72          NaN       100             21                NaN
# 109           110          NaN       100             21                NaN
# 296           297          NaN       100             21                NaN
# 416           417          NaN       100             21                NaN
# ...           ...          ...       ...            ...                ...
# 49552       49553          NaN       100             21                NaN
# 49574       49575          NaN       100             21                NaN
# 49640       49641          NaN       100             21                NaN
# 49663       49664          NaN       100             21                NaN
# 49668       49669          NaN       100             21                NaN
#
# [1258 rows x 5 columns]

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
#
# 1. Cantidad de valores ausentes: hay 1,258 productos cuyo campo product_name está acío (NaN).
#
# 2. además de product_name, las columnas como product_name_upper también aparecen vacías para esas mismas filas.
#
# 3. Patrón en los datos: todos los productos con product_name ausente pertenecen a:
# aisle_id = 100
# department_id = 21
# Esto indica que los datos faltantes están en un mismo pasillo y departamento, no distribuidos aleatoriamente, puede tratarse de un error de carga de los datos de ese pasillo/departamento, más que algo aleatorio

# %%
#  ¿Todos los nombres de productos ausentes están relacionados con el pasillo con ID 100?

missing_by_aisle = products[products['product_name'].isnull()]['aisle_id'].value_counts()
print(missing_by_aisle)
# Out:
# 100    1258
# Name: aisle_id, dtype: int64

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
# Todos los productos ausentes estan relacionados al mismo pasillo aisle_100

# %%
# ¿Todos los nombres de productos ausentes están relacionados con el departamento con ID 21?
missing_by_department = products[products['product_name'].isnull()]['department_id'].value_counts()
print(missing_by_department)
# Out:
# 21    1258
# Name: department_id, dtype: int64

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
#
# Todos los nombres de productos ausentes están relacionados con el departamento department_21

# %%
# Usa las tablas department y aisle para revisar los datos del pasillo con ID 100 y el departamento con ID 21.

aisle_info = aisles[aisles['aisle_id'] == 100]
#print("Información del pasillo con ID 100:")
print(aisle_info)

department_info = departments[departments['department_id'] == 21]
#print("\nInformación del departamento con ID 21:")
print(department_info)
# Out:
#     aisle_id    aisle
# 99       100  missing
#     department_id department
# 20             21    missing

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
#
# El aisle_id = 100 y department_id = 21 aparecen con la etiqueta “missing”.
# Esto puede indicar que hay productos que no tienen asignado un pasillo o departamento válido en el dataset, tal vez pertenecen a una categoría especial para agrupar los faltantes.

# %%
# Completa los nombres de productos ausentes con 'Unknown'
products['product_name'] = products['product_name'].fillna('Unknown')
missing_product_name = products['product_name'].isnull().sum()
print(missing_product_name)
# Out:
# 0

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br />
# Bien hecho!<br/>
# La manera de encontrar los valores ausentes y reemplazarlos con un valor generico es correcta
# </div>

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
# En lugar de dejar esos registros como NaN, se reemplazaron por la etiqueta "Unknown". Después del reemplazo, la columna product_name ya no tiene valores nulos (conteo de NaN = 0)

# %% [markdown]
# ### `orders` data frame

# %%
# Encuentra los valores ausentes
missing_instacart_orders= instacart_orders.isnull().sum()
print(missing_instacart_orders)
# Out:
# order_id                      0
# user_id                       0
# order_number                  0
# order_dow                     0
# order_hour_of_day             0
# days_since_prior_order    28819
# dtype: int64

# %%
# ¿Hay algún valor ausente que no sea el primer pedido del cliente?
first_purchase = instacart_orders.query('order_number == 1')
print(first_purchase)
# Out:
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 28        133707   182261             1          3                 10
# 96        787445    25685             1          6                 18
# 100       294410   111449             1          0                 19
# 103      2869915   123958             1          4                 16
# 104      2521921    42286             1          3                 18
# ...          ...      ...           ...        ...                ...
# 478895   2589657   205028             1          0                 16
# 478896   2222353   141211             1          2                 13
# 478922   2272807   204154             1          1                 15
# 478926   2499542    68810             1          4                 19
# 478945   1387033    22496             1          5                 14
#
#         days_since_prior_order
# 28                         NaN
# 96                         NaN
# ...

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
# order_id, columnas sin valores ausentes: user_id, order_number, order_dow,
# order_hour_of_day → todas tienen 0 valores nulos.
#
# 1. Columnas sin valores ausentes: user_id, order_number, order_dow, order_hour_of_day. Esto significa que la información sobre el cliente, el número de pedido y el momento en que se hizo (día y hora) está completa.
#
# 2. Columna con valores ausentes:days_since_prior_order presenta valores NaN, encontramos que los valores ausentes corresponden a los pedidos con order_number == 1, es decir, la primera compra de cada usuario.Tiene sentido que no exista un número de días previos para la primera orden, porque no hay una compra anterior con la cual calcular ese dato.Se identificó que los NaN en days_since_prior_order no representan un error de datos, sino que corresponden naturalmente a las primeras compras de los usuarios,se mantienen tal cual, ya que son un caso válido.

# %% [markdown]
# ### `order_products` data frame

# %%
# Encuentra los valores ausentes

missing_order_products= order_products.isnull().sum()
print(missing_order_products)
# Out:
# order_id               0
# product_id             0
# add_to_cart_order    836
# reordered              0
# dtype: int64

# %%
# ¿Cuáles son los valores mínimos y máximos en esta columna?
min_value = order_products['add_to_cart_order'].min()
max_value = order_products['add_to_cart_order'].max()

print("Valor mínimo:", min_value)
print("Valor máximo:", max_value)
# Out:
# Valor mínimo: 1.0
# Valor máximo: 64.0

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
# 1. add_to_cart_order indica el orden en el que los productos fueron añadidos al carrito en cada pedido.
# Mínimo → 1 (primer producto agregado al carrito).
# Máximo → dependerá del pedido más grande en el dataset.

# %%
# Guarda todas las IDs de pedidos que tengan un valor ausente en 'add_to_cart_order'

missing_orders = order_products[order_products['add_to_cart_order'].isnull()]['order_id'].unique()
print("Total de pedidos con valores ausentes:", len(missing_orders))
# Out:
# Total de pedidos con valores ausentes: 70

# %%
# ¿Todos los pedidos con valores ausentes tienen más de 64 productos?

# Contar productos por cada pedido con valores ausentes
products_per_order = order_products[order_products['order_id'].isin(missing_orders)] \
                        .groupby('order_id')['product_id'].count()

print("Máximo número de productos en pedidos con valores ausentes:\n", products_per_order.max())
print("Mínimo número de productos en pedidos con valores ausentes:\n", products_per_order.min())


# Agrupa todos los pedidos con datos ausentes por su ID de pedido.

missing_orders_grouped = order_products[order_products['add_to_cart_order'].isnull()] \
                            .groupby('order_id')['product_id'].count()

print("Pedidos ausentes agrupados por su Id\n",missing_orders_grouped.describe())

# Cuenta el número de 'product_id' en cada pedido y revisa el valor mínimo del conteo.
# Valor mínimo de productos en pedidos con valores ausentes
min_products_missing = missing_orders_grouped.min()
print("Mínimo número de productos en pedidos con valores ausentes:\n", min_products_missing)
# Out:
# Máximo número de productos en pedidos con valores ausentes:
#  127
# Mínimo número de productos en pedidos con valores ausentes:
#  65
# Pedidos ausentes agrupados por su Id
#  count    70.000000
# mean     11.942857
# std      12.898585
# min       1.000000
# 25%       3.000000
# 50%       7.000000
# 75%      14.000000
# max      63.000000
# Name: product_id, dtype: float64
# Mínimo número de productos en pedidos con valores ausentes:
#  1

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br />
# Cuidado!<br/>
#
# El valor minimo para ordenes que tienen valores nulos es `65`, te dejo el código en la celda de abajo
# </div>

# %%
# Código del revisor
order_products[order_products['order_id'].isin(missing_orders)].groupby('order_id')['product_id'].count().min()
# Out:
# 65

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
# Estadísticas descriptivas (los 70 pedidos con valores ausentes):
#
# count: 70 → Tienes 70 pedidos con valores faltantes
#
# mean: 11.94 → En promedio, cada pedido tiene ~12 productos
#
# std: 12.90 → Hay mucha variabilidad (desviación estándar alta)
#
# min: 1 → El pedido más pequeño tiene 1 producto
#
# 25%: 3 → 25% de pedidos tienen 3 o menos productos
#
# 50%: 7 → La mitad de pedidos tienen 7 o menos productos (mediana)
#
# 75%: 14 → 75% de pedidos tienen 14 o menos productos
#
#
# max: 63 → El pedido más grande tiene 63 productos
#
# La mayoría de pedidos con valores ausentes son pequeños (mediana de 7 productos).

# %%
# Remplaza los valores ausentes en la columna 'add_to_cart? con 999 y convierte la columna al tipo entero.

# Reemplazar valores ausentes
order_products['add_to_cart_order'] = order_products['add_to_cart_order'].fillna(999)

# Convertir a entero
order_products['add_to_cart_order'] = order_products['add_to_cart_order'].astype(int)

# Verificación
print(order_products['add_to_cart_order'].isnull().sum())
print(order_products['add_to_cart_order'].dtype)
# Out:
# 0
# int64

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br />
# Bien hecho!<br/>
# La manera de encontrar los valores ausentes y reemplazarlos con un valor generico es correcta
# </div>

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
#
# 1. Valores ausentes detectados:La columna add_to_cart_order tenía 836 valores nulos.Todos los demás campos (order_id, product_id, reordered) estaban completos.
#
# 2. Rango válido de la columna:
# El valor mínimo fue 1 (primer producto agregado al carrito).
# El valor máximo fue 64 (pedido más grande en el dataset).
#
# 3. Pedidos con valores ausentes:Se identificaron varios order_id con registros faltantes.Al agruparlos, se comprobó que algunos pedidos tenían menos de 64 productos, lo que significa que los nulos no están relacionados con superar el máximo observado (64).
# El valor mínimo de productos en un pedido con datos ausentes confirmó que incluso pedidos pequeños tenían valores faltantes.
#
# 4. Acción: Para no perder registros los valores ausentes en add_to_cart_order se reemplazaron por 999, marcándolos como “fuera del rango normal”. Después se convirtió la columna al tipo entero, eliminando inconsistencias.

# %% [markdown]
# ### Conclusiones
#
# Escribe aquí tus conclusiones intermedias sobre el Paso 2. Preprocesamiento de los datos.
#
# El pre-procesamiento de datos es fundamental porque transforma datos brutos e imperfectos en un formato limpio, consistente y adecuado para el análisis y modelado, mejorando la precisión y fiabilidad al abordar problemas como valores ausentes, duplicados, lectura y formato de datos, tras el pre-procesamiento, los datos quedaron estandarizados, consistentes y listos para análisis. Los valores ausentes fueron tratados de forma lógica según el contexto de negocio, diferenciando entre datos que debían conservarse (como la primera compra sin días previos) y aquellos que requerían eliminación para mantener la integridad del dataset.

# %% [markdown]
# # Paso 3. Análisis de los datos
#
# Una vez los datos estén procesados y listos, haz el siguiente análisis:

# %% [markdown]
# # [A] Fácil (deben completarse todos para aprobar)
#
# 1. Verifica que los valores en las columnas `'order_hour_of_day'` y `'order_dow'` en la tabla orders sean razonables (es decir, `'order_hour_of_day'` oscile entre 0 y 23 y `'order_dow'` oscile entre 0 y 6).
# 2. Crea un gráfico que muestre el número de personas que hacen pedidos dependiendo de la hora del día.
# 3. Crea un gráfico que muestre qué día de la semana la gente hace sus compras.
# 4. Crea un gráfico que muestre el tiempo que la gente espera hasta hacer su siguiente pedido, y comenta sobre los valores mínimos y máximos.

# %% [markdown]
# ### [A1] Verifica que los valores sean sensibles

# %%
# Revisar rango de order_hour_of_day
print("Mínimo order_hour_of_day:", instacart_orders['order_hour_of_day'].min())
print("Máximo order_hour_of_day:", instacart_orders['order_hour_of_day'].max())
# Out:
# Mínimo order_hour_of_day: 0
# Máximo order_hour_of_day: 23

# %%
# Revisar rango de order_dow
print("Mínimo order_dow:", instacart_orders['order_dow'].min())
print("Máximo order_dow:", instacart_orders['order_dow'].max())
# Out:
# Mínimo order_dow: 0
# Máximo order_dow: 6

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br />
# Bien hecho!<br/>
# Se verificó que los datos sean sensibles correctamente
# </div>

# %% [markdown]
# ### [A2] Para cada hora del día, ¿cuántas personas hacen órdenes?

# %%
import matplotlib.pyplot as plt

instacart_orders['order_hour_of_day'].value_counts().sort_index().plot(kind='bar', figsize=(10,5))
plt.title("Número de pedidos por hora del día")
plt.xlabel("Hora del día (0-23)")
plt.ylabel("Número de pedidos")
plt.show()

# %% [markdown]
# Los pedidos comienzan a aumentar a partir de las 7–8 a.m.
# El pico más alto se concentra entre las 10 a.m. y 3 p.m., siendo las horas más activas para realizar compras. Después de las 8 p.m. los pedidos empiezan a descender significativamente, y en la madrugada (0–5 a.m.) casi no se registran compras.
# La mayoría de los usuarios hace sus compras durante la mañana y primeras horas de la tarde.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br />
# Bien hecho!<br/>
# Buena manera de presentar los datos
# </div>

# %% [markdown]
# ### [A3] ¿Qué día de la semana compran víveres las personas?

# %%
instacart_orders['order_dow'].value_counts().sort_index().plot(kind='bar', figsize=(8,5))
plt.title("Número de pedidos por día de la semana")
plt.xlabel("Día de la semana (0=Domingo, 6=Sábado)")
plt.ylabel("Número de pedidos")
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br />
# Correcto!<br/>
# Los domingos son los días preferidos de los clientes
# </div>

# %% [markdown]
# El mayor número de pedidos ocurre en los días 0 (domingo) y 1 (lunes).
# A partir del martes (día 2) los pedidos bajan y se mantienen relativamente estables durante el resto de la semana.

# %% [markdown]
# ### [A4] ¿Cuánto tiempo esperan las personas hasta hacer otro pedido? Comenta sobre los valores mínimos y máximos.

# %%
instacart_orders['days_since_prior_order'].dropna().plot(kind='hist', bins=30, figsize=(10,5))
plt.title("Tiempo hasta el siguiente pedido")
plt.xlabel("Días desde el pedido anterior")
plt.ylabel("Número de usuarios")
plt.show()
median_value = instacart_orders['days_since_prior_order'].median()

print("Mínimo days_since_prior_order:", instacart_orders['days_since_prior_order'].min())
print("Máximo days_since_prior_order:", instacart_orders['days_since_prior_order'].max())
median_value = instacart_orders['days_since_prior_order'].median()
print("Mediana:", median_value)
# Out:
# Mínimo days_since_prior_order: 0.0
# Máximo days_since_prior_order: 30.0
# Mediana: 7.0

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br />
# Los resultados son correctos
# <br />
# Hasta este punto no podemos saber si realmente los usuarios esperan 30 días para realizar otra compra o es el sistema el que agrupa todas las compras que sean mayores a 30 días en el día 30. Con la gráfica podemos observar que la mayoría de usuarios se concentra entre 1 y 9 días donde después los números descienden gradualmente
# </div>

# %% [markdown]
# El gráfico muestra que la mayoría de los usuarios realizan sus pedidos de manera recurrente, especialmente en la primera semana tras su última compra. Existe un pico marcado en los 7 días, lo que evidencia un patrón semanal de recompra. Asimismo, se observan picos menores en 14, 21 y un pico muy alto en 30 días, lo cual sugiere que una parte de los clientes mantiene un ciclo mensual de compra indicando que los usuarios planifican compras mensuales.

# %% [markdown]
# # [B] Intermedio (deben completarse todos para aprobar)
#
# 1. ¿Existe alguna diferencia entre las distribuciones `'order_hour_of_day'` de los miércoles y los sábados? Traza gráficos de barra de `'order_hour_of_day'` para ambos días en la misma figura y describe las diferencias que observes.
# 2. Grafica la distribución para el número de órdenes que hacen los clientes (es decir, cuántos clientes hicieron solo 1 pedido, cuántos hicieron 2, cuántos 3, y así sucesivamente...).
# 3. ¿Cuáles son los 20 principales productos que se piden con más frecuencia (muestra su identificación y nombre)?

# %% [markdown]
# ### [B1] Diferencia entre miércoles y sábados para  `'order_hour_of_day'`. Traza gráficos de barra para los dos días y describe las diferencias que veas.

# %%
wednesday_orders = instacart_orders[instacart_orders['order_dow'] == 3]['order_hour_of_day']

# %%
saturday_orders = instacart_orders[instacart_orders['order_dow'] == 6]['order_hour_of_day']

# %%
plt.figure(figsize=(12,6))
plt.hist(wednesday_orders, bins=24, alpha=0.6, label='Miércoles (3)')
plt.hist(saturday_orders, bins=24, alpha=0.6, label='Sábado (6)')
plt.xlabel("Hora del día")
plt.ylabel("Número de pedidos")
plt.title("Distribución de pedidos por hora del día: Miércoles vs Sábado")
plt.legend()
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br />
# Bien hecho!
# <br />
# Buena manera de mostrar los resultados de ambos días en una misma grafica
# </div>

# %% [markdown]
# Los miércoles suelen tener mayor cantidad de  pedidos en horas laborales (mañana y primeras horas de la tarde).Los sábados presentan más dispersión, con pedidos más frecuentes en la tarde y la noche, reflejando un comportamiento de fin de semana.

# %% [markdown]
# ### [B2] ¿Cuál es la distribución para el número de pedidos por cliente?

# %%
# Contar cuántos pedidos ha hecho cada cliente
orders_per_user = instacart_orders.groupby('user_id')['order_id'].count()

# %%
# Graficar la distribución
plt.figure(figsize=(12,6))
plt.hist(orders_per_user, bins=50, edgecolor='black')
plt.xlabel("Número de pedidos por cliente")
plt.ylabel("Número de clientes")
plt.title("Distribución de número de pedidos por cliente")
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br />
# Correcto!<br/>
#
# La mayoría de usuarios no ha hecho muchos pedidos, buenas observaciones.
#
# </div>

# %% [markdown]
# La mayoría de los clientes hacen solo unos pocos pedidos (1–5).Hay un grupo más reducido de clientes que realizan muchos pedidos (más de 30), mostrando un patrón típico de plataformas de consumo masivo: muchos usuarios ocasionales y pocos muy activos

# %% [markdown]
# ### [B3] ¿Cuáles son los 20 productos más populares (muestra su ID y nombre)?

# %%
# agrupar products por product_id
top_products = products.groupby('product_id').size().reset_index(name='counts')
top_products = top_products.sort_values(by='counts', ascending=False).head(20)

# %%
# Añadir nombres de productos
top_products = top_products.merge(products[['product_id','product_name']], on='product_id', how='left')

# %%
print (top_products)
# Out:
#     product_id  counts                                      product_name
# 0            1       1                        Chocolate Sandwich Cookies
# 1        33146       1                              Revolt Killer Citrus
# 2        33124       1  Healthy Kids Organic Chocolate Nutritional Shake
# 3        33125       1              Organic Mini Cheddar Cheese Crackers
# 4        33126       1                                  Sesame Flatbread
# 5        33127       1                        No Salt Roasted Pistachios
# 6        33128       1                         Riccardo Balsamic Vinegar
# 7        33129       1                                    Classic Hummus
# 8        33130       1      Organic Salt Free Cabbage Dill Raw Sauerkrat
# 9        33131       1                        Hair Remover Wax Strip Kit
# 10       33132       1                               Mild Red Taco Sauce
# 11       33133       1          Rising Crust Spicy Italian Sausage Pizza
# ...

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br />
#
# La agrupación no es correcta, se debe usar la tabla de las ordenes, en la tabla `products` solo esta el producto y su nombre, por lo que no se puede tener un conteo correcto, Este ejercicio se resuelve de la misma manera que el ejercicio `C2` y `C5`
# </div>

# %% [markdown]
# Usualmente aparecen productos de uso común en la cocina.

# %% [markdown]
# # [C] Difícil (deben completarse todos para aprobar)
#
# 1. ¿Cuántos artículos suelen comprar las personas en un pedido? ¿Cómo es la distribución?
# 2. ¿Cuáles son los 20 principales artículos que vuelven a pedirse con mayor frecuencia (muestra sus nombres e IDs de los productos)?
# 3. Para cada producto, ¿cuál es la tasa de repetición del pedido (número de repeticiones de pedido/total de pedidos?
# 4. Para cada cliente, ¿qué proporción de los productos que pidió ya los había pedido? Calcula la tasa de repetición de pedido para cada usuario en lugar de para cada producto.
# 5. ¿Cuáles son los 20 principales artículos que la gente pone primero en sus carritos (muestra las IDs de los productos, sus nombres, y el número de veces en que fueron el primer artículo en añadirse al carrito)?

# %% [markdown]
# ### [C1] ¿Cuántos artículos compran normalmente las personas en un pedido? ¿Cómo es la distribución?

# %%
items_per_order = order_products.groupby('order_id')['product_id'].count()

# %%
print(items_per_order.describe())
# Out:
# count    450046.000000
# mean         10.098983
# std           7.540206
# min           1.000000
# 25%           5.000000
# 50%           8.000000
# 75%          14.000000
# max         127.000000
# Name: product_id, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,5))
items_per_order.hist(bins=50)
plt.xlabel("Número de artículos por pedido")
plt.ylabel("Número de pedidos")
plt.title("Distribución: artículos por pedido")
plt.show()

# %% [markdown]
#  Tiende a tener muchos pedidos, pero con pocos articulos. l mayoria de personas tinde a comprar 10 artículos .

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br />
# Bien hecho, el resultado es correcto, los usuarios suelen pedir alrededor de 10 articulos
# </div>

# %% [markdown]
# ### [C2] ¿Cuáles son los 20 principales artículos que vuelven a pedirse con mayor frecuencia (muestra sus nombres e IDs de los productos)?

# %%
# 2. Reorden por producto (y top 20 por cantidad de reorders)
product_reorders = order_products.groupby('product_id')['reordered'].agg(['sum','count']).reset_index()
product_reorders.rename(columns={'sum':'n_reorders','count':'n_orders'}, inplace=True)

# %%
# Tasa de reorden = n_reorders / n_orders
product_reorders['reorder_rate'] = product_reorders['n_reorders'] / product_reorders['n_orders']

# %%
# Top 20 por número absoluto de reorders
top20_reorders = product_reorders.sort_values(by='n_reorders', ascending=False).head(20)

# %%
# Añadir nombres
top20_reorders = top20_reorders.merge(products[['product_id','product_name']], on='product_id', how='left')

print(top20_reorders[['product_id','product_name','n_reorders','n_orders','reorder_rate']])
# Out:
#     product_id              product_name  n_reorders  n_orders  reorder_rate
# 0        24852                    Banana       55763     66050      0.844254
# 1        13176    Bag of Organic Bananas       44450     53297      0.834006
# 2        21137      Organic Strawberries       28639     37039      0.773212
# 3        21903      Organic Baby Spinach       26233     33971      0.772217
# 4        47209      Organic Hass Avocado       23629     29773      0.793639
# 5        47766           Organic Avocado       18743     24689      0.759164
# 6        27845        Organic Whole Milk       16251     19600      0.829133
# 7        47626               Large Lemon       15044     21495      0.699884
# 8        27966       Organic Raspberries       14748     19197      0.768245
# 9        16797              Strawberries       13945     20018      0.696623
# 10       26209                     Limes       13327     19690      0.676841
# ...

# %% [markdown]
# Los top por n_reorders suelen incluir productos de alta rotación en la mayoria productos orgánicos.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br />
# Correcto!<br/>
# Buena manera de mostrar los resultados, los productos naturales son consistentemente los más vendidos
# </div>

# %% [markdown]
# ### [C3] Para cada producto, ¿cuál es la proporción de las veces que se pide y que se vuelve a pedir?

# %%
# 3. Tasa de reorden para todos los productos
product_reorder_rates = product_reorders[['product_id','n_orders','n_reorders','reorder_rate']].copy()

# %%
# Opcional: añadir nombre
product_reorder_rates = product_reorder_rates.merge(products[['product_id','product_name']], on='product_id', how='left')

# %%
print(product_reorder_rates.sort_values(by='reorder_rate', ascending=False).head(20))
# Out:
#        product_id  n_orders  n_reorders  reorder_rate  \
# 13453       14721         1           1           1.0
# 19195       20949         3           3           1.0
# 6136         6723        10          10           1.0
# 6144         6732         3           3           1.0
# 41319       45088         1           1           1.0
# 41310       45078         1           1           1.0
# 19258       21016         1           1           1.0
# 19248       21005         2           2           1.0
# 32273       35192         2           2           1.0
# 32277       35197         1           1           1.0
# 6211         6810         1           1           1.0
# 41274       45040         2           2           1.0
# 41269       45035        17          17           1.0
# 25120       27373         1           1           1.0
# 28203       30748         1           1           1.0
# 41265       45031         6           6           1.0
# ...

# %% [markdown]
# los Productos con alta reorder_rate (cercana a 1) son compras recurrentes por usuarios que los conocen y vuelven a comprar.Se evidencian pocas compras ocasionales o experimentales

# %% [markdown]
# ### [C4] Para cada cliente, ¿qué proporción de sus productos ya los había pedido?

# %%
reorder_per_user = order_products.merge(instacart_orders[['order_id', 'user_id']], on='order_id', how='left')

# %%
user_stats = reorder_per_user.groupby('user_id').agg(
    total_products=('product_id', 'count'),
    n_reorders=('reordered', 'sum')
).reset_index()
user_stats['user_reorder_rate'] = user_stats['n_reorders'] / user_stats['total_products']

print(user_stats)
# Out:
#         user_id  total_products  n_reorders  user_reorder_rate
# 0             2              26           1           0.038462
# 1             4               2           0           0.000000
# 2             5              12           8           0.666667
# 3             6               4           0           0.000000
# 4             7              14          13           0.928571
# ...         ...             ...         ...                ...
# 149621   206203              27           6           0.222222
# 149622   206206              21          15           0.714286
# 149623   206207              46          41           0.891304
# 149624   206208             125          87           0.696000
# 149625   206209              25           8           0.320000
#
# [149626 rows x 4 columns]

# %% [markdown]
# La Mayoría de clientes suelen repetir sus compras.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br />
# Correcto!<br/>
# Buena manera de realizar las proporciones
# </div>

# %% [markdown]
# ### [C5] ¿Cuáles son los 20 principales artículos que las personas ponen primero en sus carritos?

# %%
# 5. Primer artículo en el carrito (add_to_cart_order == 1)
first_in_cart = order_products[order_products['add_to_cart_order'] == 1]

# %%
#Agrupar por producto Id
first_counts = first_in_cart.groupby('product_id').size().reset_index(name='n_first_times')
first_counts = first_counts.sort_values(by='n_first_times', ascending=False).head(20)

# %%
# Añadir nombre
first_counts = first_counts.merge(products[['product_id','product_name']], on='product_id', how='left')

print(first_counts[['product_id','product_name','n_first_times']])
# Out:
#     product_id                 product_name  n_first_times
# 0        24852                       Banana          15562
# 1        13176       Bag of Organic Bananas          11026
# 2        27845           Organic Whole Milk           4363
# 3        21137         Organic Strawberries           3946
# 4        47209         Organic Hass Avocado           3390
# 5        21903         Organic Baby Spinach           3336
# 6        47766              Organic Avocado           3044
# 7        19660                 Spring Water           2336
# 8        16797                 Strawberries           2308
# 9        27966          Organic Raspberries           2024
# 10       44632   Sparkling Water Grapefruit           1914
# 11       49235          Organic Half & Half           1797
# 12       47626                  Large Lemon           1737
# 13         196                         Soda           1733
# 14       38689     Organic Reduced Fat Milk           1397
# ...

# %% [markdown]
# Los primeros productos que los clientes ponen en sus carritos pertenecen al grupo de frutas y verduras. Es probable que sea la primera sección que aparece en la plataforma.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br />
# Correcto!<br/>
# Una vez más los productos orgánicos estan en el top de la lista<br/>
# </div>

# %% [markdown]
# ### Conclusion general del proyecto:

# %% [markdown]
# Conclusión del Proyecto
#
# El desarrollo del proyecto Llena tu carrito me permitió comprender la importancia
# de cada dato registrado en una plataforma de compras en línea, desde el
# identificador del producto y del usuario hasta la fecha, la hora de la transacción
# y la frecuencia de compra.
#
# Cada elemento aporta valor a la construcción de información confiable que
# refleja los hábitos de consumo de los clientes de la aplicación Intacar.
# Uno de los aspectos más relevantes fue el proceso de limpieza y estandarización
# de los datos. Esta fase resultó esencial para garantizar la calidad del análisis,
# ya que permitió identificar y corregir tipos de datos incorrectos, valores ausentes
# o duplicados que, de no tratarse, hubieran generado conclusiones equivocadas.
# A través de este trabajo se logró transformar un conjunto inicial de datos
# imperfectos en un recurso uniforme y consistente, listo para ser utilizado en la
# toma de decisiones.
# Asimismo, la elaboración de gráficos y visualizaciones fue un complemento
# fundamental, ya que proporcionó un panorama más claro y preciso de los patrones
# de compra. Estos elementos visuales no solo facilitaron la interpretación de la
# información, sino que también ayudaron a establecer relaciones entre distintas
# variables, como productos, usuarios y niveles de satisfacción.
#
# En términos personales, considero que este proyecto presentó un nivel de
# complejidad mayor en comparación con los anteriores, lo que requirió más
# tiempo para asimilar las preguntas y aplicar correctamente las herramientas
# aprendidas en sprints previos. Fue necesario repasar conceptos y funciones de
# programación para superar errores de concepto y seleccionar los métodos adecuados.
#
# En conclusión, esta experiencia me permitió consolidar competencias en
# el procesamiento y análisis de datos, reforzar la importancia de la limpieza
# y estandarización, y obtener una visión más profunda sobre cómo los datos
# estructurados pueden revelar tendencias significativas en los hábitos de
# consumo. Sin duda, el proyecto aportó un aprendizaje valioso y práctico que
# fortalece mi formación en análisis de datos aplicado a contextos reales.

# %% [markdown]
# ## Comentario general del revisor
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br />
# Has realizado un buen trabajo, me doy cuenta de que has aplicado los conocimientos que has adquirido durante el curso, las conclusiones a las que llegaste son buenas y los procedimientos realizados son correctos. Considero que este es un proyecto que se empieza a asemejar más a algún proyecto que te pidan en un trabajo, a partir de análisis de este tipo se pueden diseñar estrategias de marketing específicas para ciertos productos o se pueden optimizar los procesos internos para tener disponibles más rápidamente los productos que se venden más seguido.<br/>
#
#
# Continúa con el buen trabajo y mucho éxito en el siguiente Sprint!
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Aspectos positivos del proyecto</b> <a class="tocSkip"></a><br />
#
# - Las observaciones intermedias, así como las conclusiones finales me parecen buenas
# - Las graficas utilizadas me parecen del tipo correcto
# - El proyecto esta ordenado
#
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Aspectos que pueden mejorar del proyecto</b> <a class="tocSkip"></a><br />
#
# - Utilizar markdown para mejorar la presentación de las conclusiones finales
#
# </div>
